# %% [markdown]
# # Project 2: Ames Housing Data Analysis
#
# ## Problem Statement
#
# Given that the current pandemic has brought upon a recession, our real estate investment company would like to find out what are strong predictors of housing prices during these difficult times. To do so, we will be examining a similar turbulent period, which are the years of the subprime crisis. By using data during a similar hostile investment climate, we hope to be able to predict housing prices to guide the company's investment strategy.
#
# ## Executive Summary
#
# As a newly hired data scientist, I have been tasked to predict housing prices so as to facilitate the investment decisions of the company. By analysing the given data, coupled with external research, I aim to to generate actionable insights for the organisation to achieve larger margins in their investment strategy.
#
# ## Notebooks:
# - [Data Cleaning and Exploratory Data Analysis](./data_cleaning_EDA.ipynb)
# - [Feature Engineering and Selection](./feature_engineering_selection.ipynb)
# - [Preprocessing and Modeling](./preprocesing_and_modeling.ipynb)
# - [Conclusions and Recommendations](./conclusions_and_recommendations.ipynb)
#
# ## Contents:
# - [Import Libraries](#Import-Libraries)
# - [Import Data](#Import-Data)
# - [Data Cleaning](#Data-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#display all rows and columns of dataframe
pd.set_option("max_rows", None)
pd.set_option('max_columns', None)

# %% [markdown]
# ### Import Data

# %%
#read data and import into notebook 
ames_train=pd.read_csv('../datasets/train.csv')
ames_test=pd.read_csv('../datasets/test.csv')

# %%
ames_train.shape
# Out:
# (2051, 81)

# %%
ames_test.shape
# Out:
# (879, 80)

# %%
ames_train.columns
# Out:
# Index(['Id', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
#        'Fireplaces', 'Fireplace Qu', 'Garage Type', 'Garage Yr Blt',
#        'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Pool QC',
#        'Fence', 'Misc Feature', 'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type',
#        'SalePrice'],
#       dtype='object')

# %%
ames_test.columns
# Out:
# Index(['Id', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
#        'Fireplaces', 'Fireplace Qu', 'Garage Type', 'Garage Yr Blt',
#        'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Pool QC',
#        'Fence', 'Misc Feature', 'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type'],
#       dtype='object')

# %% [markdown]
# ##### Observation:
# The only columns missing from the test data set is the sale price column, which is normal since we are trying to predict that.
#
# Now we will concat the 2 dataframes tgt for cleaning. This will ensure that our data is cleaned in a consistent manner

# %%
ames=pd.concat([ames_train,ames_test],ignore_index=True)

# %%
ames.shape
# Out:
# (2930, 81)

# %%
ames.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        RRAe        Norm      1Fam      2Story             6             8
# 1        Norm        Norm      1Fam      2Story             7             5
# 2        Norm        Norm      1Fam      1Story             5             7
# 3        Norm        Norm      1Fam      2Story             5             5
# 4        Norm        Norm      1Fam      1.5Fin             6             8
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1976            2005      Gable   CompShg      HdBoard      Plywood
# 1        1996            1997      Gable   CompShg      VinylSd      VinylSd
# 2        1953            2007      Gable   CompShg      VinylSd      VinylSd
# 3        2006            2007      Gable   CompShg      VinylSd      VinylSd
# 4        1900            1993      Gable   CompShg      Wd Sdng      Plywood
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0      BrkFace         289.0         Gd         TA     CBlock        TA
# 1      BrkFace         132.0         Gd         TA      PConc        Gd
# 2         None           0.0         TA         Gd     CBlock        TA
# 3         None           0.0         TA         TA      PConc        Gd
# 4         None           0.0         TA         TA      PConc        Fa
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            GLQ         533.0            Unf
# 1        TA            No            GLQ         637.0            Unf
# 2        TA            No            GLQ         731.0            Unf
# 3        TA            No            Unf           0.0            Unf
# 4        Gd            No            Unf           0.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0        192.0          725.0    GasA         Ex           Y
# 1           0.0        276.0          913.0    GasA         Ex           Y
# 2           0.0        326.0         1057.0    GasA         TA           Y
# 3           0.0        384.0          384.0    GasA         Gd           Y
# 4           0.0        676.0          676.0    GasA         TA           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr         725         754                0         1479
# 1      SBrkr         913        1209                0         2122
# 2      SBrkr        1057           0                0         1057
# 3      SBrkr         744         700                0         1444
# 4      SBrkr         831         614                0         1445
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             0.0             0.0          2          1              3
# 1             1.0             0.0          2          1              4
# 2             1.0             0.0          1          0              3
# 3             0.0             0.0          2          1              3
# 4             0.0             0.0          2          0              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           Gd              6        Typ           0
# 1              1           Gd              8        Typ           1
# 2              1           Gd              5        Typ           0
# 3              1           TA              7        Typ           0
# 4              1           TA              6        Typ           0
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0          NaN      Attchd         1976.0           RFn          2.0
# 1           TA      Attchd         1997.0           RFn          2.0
# 2          NaN      Detchd         1953.0           Unf          1.0
# 3          NaN     BuiltIn         2007.0           Fin          2.0
# 4          NaN      Detchd         1957.0           Unf          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        475.0          TA          TA           Y             0
# 1        559.0          TA          TA           Y             0
# 2        246.0          TA          TA           Y             0
# 3        400.0          TA          TA           Y           100
# 4        484.0          TA          TA           N             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             44               0           0             0          0     NaN
# 1             74               0           0             0          0     NaN
# 2             52               0           0             0          0     NaN
# 3              0               0           0             0          0     NaN
# 4             59               0           0             0          0     NaN
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
# 0   NaN          NaN         0        3     2010       WD    130500.0
# 1   NaN          NaN         0        4     2009       WD    220000.0
# 2   NaN          NaN         0        1     2010       WD    109000.0
# 3   NaN          NaN         0        4     2010       WD    174000.0
# 4   NaN          NaN         0        3     2010       WD    138500.0

# %% [markdown]
# ##### First observations:
# - Column names contain spacing and are capitalised
# - There are NaN values observed. Check for that
# - Check data types

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Rename Columns

# %%
#create a list of names for each column
col_names=[col.lower().replace(' ','_') for col in ames.columns]

#rename columns with list
ames.columns=col_names

#check changes
ames.head()
# Out:
#     id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   lot_shape land_contour utilities lot_config land_slope neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   condition_1 condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 0        RRAe        Norm      1Fam      2Story             6             8
# 1        Norm        Norm      1Fam      2Story             7             5
# 2        Norm        Norm      1Fam      1Story             5             7
# 3        Norm        Norm      1Fam      2Story             5             5
# 4        Norm        Norm      1Fam      1.5Fin             6             8
#
#    year_built  year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# 0        1976            2005      Gable   CompShg      HdBoard      Plywood
# 1        1996            1997      Gable   CompShg      VinylSd      VinylSd
# 2        1953            2007      Gable   CompShg      VinylSd      VinylSd
# 3        2006            2007      Gable   CompShg      VinylSd      VinylSd
# 4        1900            1993      Gable   CompShg      Wd Sdng      Plywood
#
#   mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 0      BrkFace         289.0         Gd         TA     CBlock        TA
# 1      BrkFace         132.0         Gd         TA      PConc        Gd
# 2         None           0.0         TA         Gd     CBlock        TA
# 3         None           0.0         TA         TA      PConc        Gd
# 4         None           0.0         TA         TA      PConc        Fa
#
#   bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 0        TA            No            GLQ         533.0            Unf
# 1        TA            No            GLQ         637.0            Unf
# 2        TA            No            GLQ         731.0            Unf
# 3        TA            No            Unf           0.0            Unf
# 4        Gd            No            Unf           0.0            Unf
#
#    bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 0           0.0        192.0          725.0    GasA         Ex           Y
# 1           0.0        276.0          913.0    GasA         Ex           Y
# 2           0.0        326.0         1057.0    GasA         TA           Y
# 3           0.0        384.0          384.0    GasA         Gd           Y
# 4           0.0        676.0          676.0    GasA         TA           Y
#
#   electrical  1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 0      SBrkr         725         754                0         1479
# 1      SBrkr         913        1209                0         2122
# 2      SBrkr        1057           0                0         1057
# 3      SBrkr         744         700                0         1444
# 4      SBrkr         831         614                0         1445
#
#    bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 0             0.0             0.0          2          1              3
# 1             1.0             0.0          2          1              4
# 2             1.0             0.0          1          0              3
# 3             0.0             0.0          2          1              3
# 4             0.0             0.0          2          0              3
#
#    kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 0              1           Gd              6        Typ           0
# 1              1           Gd              8        Typ           1
# 2              1           Gd              5        Typ           0
# 3              1           TA              7        Typ           0
# 4              1           TA              6        Typ           0
#
#   fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
# 0          NaN      Attchd         1976.0           RFn          2.0
# 1           TA      Attchd         1997.0           RFn          2.0
# 2          NaN      Detchd         1953.0           Unf          1.0
# 3          NaN     BuiltIn         2007.0           Fin          2.0
# 4          NaN      Detchd         1957.0           Unf          2.0
#
#    garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
# 0        475.0          TA          TA           Y             0
# 1        559.0          TA          TA           Y             0
# 2        246.0          TA          TA           Y             0
# 3        400.0          TA          TA           Y           100
# 4        484.0          TA          TA           N             0
#
#    open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  pool_area pool_qc  \
# 0             44               0           0             0          0     NaN
# 1             74               0           0             0          0     NaN
# 2             52               0           0             0          0     NaN
# 3              0               0           0             0          0     NaN
# 4             59               0           0             0          0     NaN
#
#   fence misc_feature  misc_val  mo_sold  yr_sold sale_type  saleprice
# 0   NaN          NaN         0        3     2010       WD    130500.0
# 1   NaN          NaN         0        4     2009       WD    220000.0
# 2   NaN          NaN         0        1     2010       WD    109000.0
# 3   NaN          NaN         0        4     2010       WD    174000.0
# 4   NaN          NaN         0        3     2010       WD    138500.0

# %% [markdown]
# #### Null Values

# %%
#check for null values
#because the data set is really big, we first identify the columns that contain null values
null_columns=ames.columns[ames.isnull().any()]
#sum the number of null values in each column in null_columns
ames[null_columns].isnull().sum()
# Out:
# lot_frontage       490
# alley             2732
# mas_vnr_type        23
# mas_vnr_area        23
# bsmt_qual           80
# bsmt_cond           80
# bsmt_exposure       83
# bsmtfin_type_1      80
# bsmtfin_sf_1         1
# bsmtfin_type_2      81
# bsmtfin_sf_2         1
# bsmt_unf_sf          1
# total_bsmt_sf        1
# electrical           1
# bsmt_full_bath       2
# bsmt_half_bath       2
# fireplace_qu      1422
# garage_type        157
# garage_yr_blt      159
# garage_finish      159
# garage_cars          1
# garage_area          1
# garage_qual        159
# garage_cond        159
# pool_qc           2917
# fence             2358
# misc_feature      2824
# saleprice          879
# dtype: int64

# %% [markdown]
# ##### Decisions for null values
# - For columns with 2 or less nulls, I will drop the rows with the null values since they are a small proportion of the dataset
# - For columns with extremely high numbers of nan such as alley, pool and misc_feature, we will be dropping these columns as the lack of data will be statistically insignificant and lead to dimensonality error/bias
# - For mas_vnr_xxx/garage_xx, it seems like there are missing values  because there is no such feature in the property in the first place. We will replace nan with 0 for these variables.
# - For variables such as garage_yr built, we will impute it with the year the house was built which is the norm for most houses with a garage
# - Lastly, for continuous variables such as lot frontage, we will be imputing with mean values based on the lot shape and lot area

# %%
#since we will be replacing a large number of columns with na values to 0
#let's build a function to do it
def na_to_0(list_of_col):
    for i in list_of_col:
        ames.fillna({i:0,},inplace=True)

# %% [markdown]
# Now let's get to cleaning!

# %%
#since this row contains both the null values in garage_cars and area,
#we will drop this row. 
ames.drop(list(ames[ames['garage_cars'].isnull()].index),inplace=True)

# %%
#since both row contains both the null values in bsmt_full_bath and bsmt_half_bath,
#we will drop these rows. 
ames.drop(list(ames[ames['bsmt_full_bath'].isnull()].index),inplace=True)

# %%
#similarly, this row has 1 missing value so we will be dropping it
ames.drop(list(ames[ames['electrical'].isnull()].index),inplace=True)

# %%
#these columns have high numbers of missing data -> statistically insignificant
ames.drop(['alley','pool_qc','misc_feature','fence'],axis=1,inplace=True)
ames.shape
#dropped 4 columns and 3 rows
# Out:
# (2926, 77)

# %%
#next we take a look at the columns starting with garage_xx

ames[ames['garage_type'].isnull()].loc[:,['garage_type','garage_yr_blt','garage_finish','garage_qual','garage_cond','garage_area']].shape
# Out:
# (157, 6)

# %% [markdown]
# Here we can see that all the null values in the garage_xxx series are all in the same 113 rows of data
# Since we have double checked against garage_area which are zero for the null values (which means there is no garage), we will replace them with 0
#
# For the numerical variables such as garage_yr_blt, we will impute it with yr_built, which we observed to be the same from houses with garages.

# %%
#use our function to replace na with 0
na_to_0(['garage_type','garage_finish','garage_qual','garage_cond'])

# %%
#impute garage_yr_blt with yr_built
ames['garage_yr_blt'].fillna(ames['year_built'],inplace=True)

# %%
ames[ames['bsmt_exposure'].isnull()].loc[:,['bsmt_qual','bsmt_cond','bsmt_exposure','bsmtfin_type_1','bsmtfin_type_2']].head()
#the bsmt_exposure col has some rows that should be 'No' instead of na
# we will replace those first
# Out:
#     bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1 bsmtfin_type_2
# 12        NaN       NaN           NaN            NaN            NaN
# 93        NaN       NaN           NaN            NaN            NaN
# 114       NaN       NaN           NaN            NaN            NaN
# 146       NaN       NaN           NaN            NaN            NaN
# 183       NaN       NaN           NaN            NaN            NaN

# %%
#replace na with 'No'
ames.loc[ames['bsmt_cond'] == 'TA', 'bsmt_exposure'] = 'No'

# %%
na_to_0(['bsmt_qual','bsmt_cond','bsmt_exposure','bsmtfin_type_1','bsmtfin_type_2'])

# %%
#now we look at the mas_vnr_xx columns
ames[ames['mas_vnr_area'].isnull()].loc[:,['mas_vnr_type','mas_vnr_type']].shape
# Out:
# (23, 2)

# %%
ames[ames['fireplace_qu'].isnull()]['fireplace_qu'].shape
# Out:
# (1419,)

# %%
#for the above 3 columns, we replace nan with 0
na_to_0(['mas_vnr_area','mas_vnr_type','fireplace_qu'])

# %%
#lastly, we will take a look at the lot_frontage data
ames['lot_frontage'].unique()
lots=ames[['lot_frontage','lot_area','lot_shape','lot_config']]

#using external research, we have determined that the shape of the lot will give us an accurate 
#estimation of the lot frontage

#firstly, we groupby lot shape to see the mean of lot area and frontage
lot_shapes=lots.groupby('lot_shape').mean()

#next, we calculate a ratio to help determine the missing lot frontage based on
#lot shape and lot area mean
lot_shapes['area_frontage_ratio']=lot_shapes['lot_area']/lot_shapes['lot_frontage']
lot_shapes
# Out:
#            lot_frontage      lot_area  area_frontage_ratio
# lot_shape
# IR1           74.703988  11513.646878           154.123591
# IR2           67.437500  18913.065789           280.453246
# IR3          117.636364  32064.187500           272.570373
# Reg           66.855072   8865.059774           132.601154

# %%
area_front_ratio={'IR1':154.12,'IR2':280.45,
                  'IR3':272.57,'Reg':132.49}

ames['lot_frontage']=ames['lot_area']/ames['lot_shape'].map(area_front_ratio)

# %%
#check changes
ames['lot_frontage'].head()
# Out:
# 0    87.704386
# 1    74.565274
# 2    59.793192
# 3    73.982942
# 4    92.363094
# Name: lot_frontage, dtype: float64

# %%
#check for changes
ames.shape
# Out:
# (2926, 77)

# %% [markdown]
# #### Other Data Cleaning
#
# Now that we are done with removing the nulls, we will move on to clean our data further by removing unnecessary rows

# %%
#check for the types of zoning classification
ames['ms_zoning'].unique()
# Out:
# array(['RL', 'RM', 'FV', 'C (all)', 'A (agr)', 'RH', 'I (all)'],
#       dtype=object)

# %%
#find all transactions that are commercial and industrial -> 20 rows
ames[(ames['ms_zoning']=='C (all)')|(ames['ms_zoning']=='I (all)')]
#we will drop these rows as it could affect the residential sale prices
ames.drop(list(ames[(ames['ms_zoning']=='C (all)')|(ames['ms_zoning']=='I (all)')].index),axis=0,inplace=True)
ames.shape
# Out:
# (2899, 77)

# %%
#the pid is a unique identifier for every house in ames. I believe that there is a breakdown that
#I could not find which could be used as a proxy for location
#for our current purposes, we will leave it out 
ames.drop('pid',axis=1,inplace=True)

# %%
plt.hist(ames['utilities']);
#here we can see that almost the whole column is AllPub and probably bears no statistical significanc
#as such, we will drop the utilities column
ames.drop('utilities',axis=1,inplace=True)

# %%
ames.shape
# Out:
# (2899, 75)

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# First, let's take a quick look at the correlation matrix

# %%
# Establish size of figure.
plt.figure(figsize=(30,30))

corr = ames.corr()

# Set up mask to be "True" in the upper triangle. (triu)
#use (tril) for lower triangle
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap, while masking the upper triangle to be white.
with sns.axes_style("white"):
    sns.heatmap(corr, mask=mask, vmax=0.3, square=True, annot=True, cmap='coolwarm')

# %% [markdown]
# Here are some of the features with the highest corr to saleprice:
# - overall_qual
# - gr_liv_area
# - garage_area
#
# These features are highly correlated:
# - lot area and lot frontage
# - garage_yyr_built and year_built
# - 1st_flr_sf and total_bsmt_sf
# - garage cars and garage area
#
# These features might tell us which to create polynomial features for, to capture non-linear relationships in the data

# %%
#here we can have a better idea of the correlation of the numbberical variables
pd.DataFrame(ames.corr()['saleprice'].sort_values(ascending=False))
#this only shows the corr of numerical variables, not categorical
# Out:
#                  saleprice
# saleprice         1.000000
# overall_qual      0.797948
# gr_liv_area       0.695995
# garage_area       0.647668
# garage_cars       0.644563
# total_bsmt_sf     0.627708
# 1st_flr_sf        0.617907
# year_built        0.564570
# garage_yr_blt     0.545179
# year_remod/add    0.543254
# full_bath         0.532173
# mas_vnr_area      0.502160
# totrms_abvgrd     0.500959
# fireplaces        0.464353
# bsmtfin_sf_1      0.420440
# open_porch_sf     0.345863
# wood_deck_sf      0.322816
# lot_area          0.296822
# lot_frontage      0.291330
# bsmt_full_bath    0.278755
# half_bath         0.276712
# 2nd_flr_sf        0.247371
# bsmt_unf_sf       0.190372
# screen_porch      0.132200
# bedroom_abvgr     0.126749
# 3ssn_porch        0.049222
# mo_sold           0.037938
# pool_area         0.022500
# bsmtfin_sf_2      0.012735
# misc_val         -0.008576
# yr_sold          -0.012974
# low_qual_fin_sf  -0.038309
# bsmt_half_bath   -0.049134
# id               -0.051455
# ms_subclass      -0.091399
# overall_cond     -0.107609
# enclosed_porch   -0.125099
# kitchen_abvgr    -0.126924

# %% [markdown]
# #### Identifying variables for the features matrix
# First, we check for variable with the strongest correlation to sale prices
#
# Naturally, we would expect property size variables to be the most strongly correlated. Following that, we will be having a closer look at location variables, condition variables and lastly, amenities.

# %% [markdown]
# #### List of potential numerical variables
# 1. overall_qual (amenities)
# 2. gr_liv_area (property size)
# 3. total_bsmt_sf (amenities, property size)
# 4. garage_area (amenities, property size)
# 5. year_built (condition)
# 6. full_bath (amenities)
# 7. mas_vnr_area (amenities)
# 8. totrms_abvgrd (property size, amnenities)
# 9. fireplace_qu_Gd (amenities
# 10. lot_area (property size)
# 11. year_remod/add (condition)

# %% [markdown]
# but first let's take a look at the highest correlated variables to saleprice

# %%
#since gr_liv_area has a strong correlation with saleprice, let's take a look at it in a scatter plot
plt.figure(figsize=(12,10))
plt.scatter(ames['gr_liv_area'],ames['saleprice'])

plt.title('Sale Prices of Homes Sold by Square Feet of Living Area',fontsize=25)
plt.ylabel('Sale Prices of Homes Sold',fontsize=20)
plt.xlabel('Square Feet of Living Area',fontsize=20);

# %% [markdown]
# ##### Observations
# There is a strong correlation between the sale prices and the square feet of living area. We will definitely be including this in our model.
#
# Here we can see that there are 2 houses with extremely huge living areas being sold at abonormally low prices.
# There are likely outliers. let's confirm with a boxplot.

# %%
plt.figure(figsize=(10,8))

plt.boxplot(ames['gr_liv_area'],showmeans=True)
plt.title('Boxplot of the square feet of living area',fontsize=25)
plt.ylabel('Square Feet of Living Area',fontsize=20);

#to further confirm, we will calculate the number of std away from the mean
ames['gr_liv_area'].mean()+5*ames['gr_liv_area'].std()

#since the outliers are more than 5std away from the mean, we will remove them from the dataset
# Out:
# 4018.8505746581686

# %%
ames.shape
# Out:
# (2899, 75)

# %%
#drop the outliers
ames.drop(list(ames[ames['gr_liv_area']>4000].index),inplace=True)

# %%
#confirm changes
ames.shape
# Out:
# (2894, 75)

# %%
#from the boxplot, the distribution seems to look normal with a right skew
#let's take look at the histogram
plt.figure(figsize=(12,10))
plt.hist(ames['gr_liv_area'],bins=17);


ames['gr_liv_area'].describe()
# Out:
# count    2894.000000
# mean     1496.526952
# std       483.804056
# min       334.000000
# 25%      1130.250000
# 50%      1444.500000
# 75%      1741.500000
# max      3672.000000
# Name: gr_liv_area, dtype: float64

# %%
#next we look at garage area
plt.figure(figsize=(12,10))
plt.boxplot(ames['garage_area'],showmeans=True)

plt.title('Boxplot of Garage Area',fontsize=25)
plt.ylabel('Garage Area',fontsize=20);

# %%
#Looks like there are some outliers here 
#to further confirm, we will calculate the number of std away from the mean
ames['garage_area'].mean()+4*ames['garage_area'].std()
# Out:
# 1322.2157870594185

# %%
ames.shape
# Out:
# (2894, 75)

# %%
#we remove all values above 1317 aka 4sd from mean
ames.drop(list(ames[ames['garage_area']>1317].index),inplace=True)

# %%
ames.shape
# Out:
# (2890, 75)

# %%
#next we look at total_bsmt_sf against sale prices 
plt.figure(figsize=(12,10))
plt.scatter(ames['total_bsmt_sf'],ames['saleprice'])

plt.title('Sale Prices of Homes Sold by Square Feet of Basement Area',fontsize=25)
plt.ylabel('Sale Prices of Homes Sold',fontsize=20)
plt.xlabel('Square Feet of Basement Area',fontsize=20);

# %%
ames.shape
# Out:
# (2890, 75)

# %%
# again, there are some outlier which we will remove
#ames.drop(list(ames[ames['total_bsmt_sf']>1400].index),inplace=True)

# %%
ames.shape
# Out:
# (2890, 75)

# %%
#next we look at a location variable
plt.figure(figsize=(12,10))
plt.scatter(ames['neighborhood'],ames['saleprice'])

plt.title('Sale Prices of Homes Sold by Neighborhood',fontsize=25)
plt.ylabel('Sale Prices of Homes Sold',fontsize=20)
plt.xlabel('Neighborhood of Homes Sold',fontsize=20)
plt.xticks(rotation=45);

# %% [markdown]
# ##### Observations:
# Here we can see that the less preferred neighborhoods are in the middle while the ones on the right seems to be expensive and few

# %% [markdown]
# #### Distribution of the Target Variable

# %%
# #let's take a look at the distribution of sale price
# plt.figure(figsize=(14,10))
# plt.hist(ames['saleprice'],bins=20)
# plt.title('Sale Price Histogram',fontsize=30)
# plt.xlabel('Sale Price ($)',fontsize=15);

#runtime caused by nan

# %% [markdown]
# ##### Observation of the distribution
# The distribution of sale prices is skewed to the right, given the long tail of the curve. This means that the median is less than the mean.

# %%
#given that the sales years includes the subprime financial crisis, there will definitely be an impact
#on sale prices
saleprice_yr=ames.groupby('yr_sold')['saleprice'].mean()

plt.figure(figsize=(12,10))
plt.plot(saleprice_yr)

plt.title('Mean Sale Prices of Homes Sold by Year',fontsize=25)
plt.ylabel('Sale Prices of Homes Sold ($)',fontsize=20)
plt.xlabel('Year Sold',fontsize=20,);

# %% [markdown]
# ##### Observation:
# Here we can see that sale prices has been falling since 2007 but doesnt seem too meaningful. Let's create a new variable to better see the relationship

# %%
#now that we are done with EDA let's save the new dataframe to csv
ames.to_csv('../datasets/combined_clean.csv',index=False)

# %%
ames.shape
# Out:
# (2930, 75)

# %%
test_id=[id for id in ames_test.Id]
type(test_id)
# Out:
# list

# %%
#ames_id=[id for id in ames.id]
len(ames_id)
# Out:
# 2930

# %%
#ames_idx_id=pd.DataFrame(ames,index=ames_id)

# %%
#test_clean=ames_idx_id.loc[test_id,:]

# %%
#test_clean.to_csv('../datasets/ames_clean.csv',index=False)

# %% [markdown]
# #### Next Steps:
# Having now gotten most of the features that we want, we will now proceed to establishing a baseline for our model in the preprocessing and modeling notebook.
#
# [Feature Engineering and Selection](./feature_engineering_selection.ipynb)
